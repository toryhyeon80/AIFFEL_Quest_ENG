# %% [markdown]
# # DP08 — Colab 7B 실내 추천 비교
#
# 런타임: **GPU (T4 권장)**
# 결과: `06_Deployment/DP08/assets/indoor_compare_7B_colab.md`
#
# 완료 후 해당 md 파일을 다운로드해 로컬 `DP08/assets/`에 넣으면 됩니다.

# %%
# GPU 확인
# !nvidia-smi

# %%
# 레포 준비 (이미 clone 했다면 pull만)
import os
if not os.path.isdir('/content/AIFFEL_Quest_ENG'):
    # !git clone https://github.com/toryhyeon80/AIFFEL_Quest_ENG.git /content/AIFFEL_Quest_ENG
# %cd /content/AIFFEL_Quest_ENG
# !git pull origin main
# %cd 06_Deployment/DP08
# !pip install -q transformers accelerate torch sentencepiece

# %%
# 7B 실내 추천 시나리오 3개 실행 (수 분~십수 분 소요 가능)
# 중단하지 말고 끝까지 두세요.
# !python scripts/compare_indoor_colab.py --models 7B

# %%
# 결과 미리보기 + 경로 확인
from pathlib import Path
p = Path('assets/indoor_compare_7B_colab.md')
print('exists:', p.exists(), p.resolve())
print(p.read_text(encoding='utf-8')[:2000] if p.exists() else 'missing')

# %% [markdown]
# ## 끝난 뒤
#
# 1. 왼쪽 파일에서 `assets/indoor_compare_7B_colab.md` 다운로드
# 2. 로컬 `06_Deployment/DP08/assets/`에 저장
# 3. 채팅에 「7B 결과 받았어」라고 알려 주세요 → 문서 반영·커밋 도와드리겠습니다.
